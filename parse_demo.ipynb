# %%
from parse import parse

with open('examples/short.smv') as f:
    input = f.read()
parse(input)
# Out:
# {'boolean_variables': ['request'],
#  'enum_variables': ['state'],
#  'enum_values': [['ready', 'busy']],
#  'invar': [],
#  'init': [(state = ready)],
#  'trans': [(((state = ready) ∧ request) → (next(state) = busy))],
#  'ltl': [G (request → F (state = busy)), G (request → XF (state = busy))]}

# %%
from parse import parse

with open('examples/hanoi.smv') as f:
    input = f.read()
parse(input)
# Out:
# {'boolean_variables': [],
#  'enum_variables': ['move', 'd4', 'd3', 'd2', 'd1'],
#  'enum_values': [['m1', 'm2', 'm3', 'm4'],
#   ['left', 'middle', 'right'],
#   ['left', 'middle', 'right'],
#   ['left', 'middle', 'right'],
#   ['left', 'middle', 'right']],
#  'invar': [¬((move = m1) ∧ (d1 ∈ [d2, d3, d4])),
#   ¬((move = m2) ∧ (d2 ∈ [d3, d4])),
#   ¬((move = m3) ∧ (d3 = d4))],
#  'init': [((d1 = left) ∧ ((d2 = left) ∧ ((d3 = left) ∧ (d4 = left))))],
#  'trans': [((move = m1) ∨ (next(d1) = d1)),
#   ((move = m2) ∨ (next(d2) = d2)),
#   ((move = m3) ∨ (next(d3) = d3)),
#   ((move = m4) ∨ (next(d4) = d4)),
#   ¬((move = m1) ∧ (next(d1) ∈ [d2, d3, d4])),
#   ¬((move = m2) ∧ (next(d2) ∈ [d3, d4])),
#   ¬((move = m3) ∧ (next(d3) = d4))],
#  'ltl': [¬F ((d1 = right) ∧ ((d2 = right) ∧ ((d3 = right) ∧ (d4 = right))))]}

# %%
from parse import parse

with open('examples/ferryman.smv') as f:
    input = f.read()
parse(input)
# Out:
# {'boolean_variables': [],
#  'enum_variables': ['move', 'cabbage', 'goat', 'wolf', 'farmer'],
#  'enum_values': [['w', 'g', 'c', 'none'],
#   ['left', 'right'],
#   ['left', 'right'],
#   ['left', 'right'],
#   ['left', 'right']],
#  'invar': [((move = w) → (wolf = farmer)),
#   ((move = g) → (goat = farmer)),
#   ((move = c) → (cabbage = farmer)),
#   ((wolf = goat) → (wolf = farmer)),
#   ((goat = cabbage) → (goat = farmer))],
#  'init': [(farmer = left), (wolf = left), (goat = left), (cabbage = left)],
#  'trans': [¬(next(farmer) = farmer),
#   ((move = w) ∨ (next(wolf) = wolf)),
#   ((move = g) ∨ (next(goat) = goat)),
#   ((move = c) ∨ (next(cabbage) = cabbage)),
#   ((move = w) → ¬(next(wolf) = wolf)),
#   ((move = g) → ¬(next(goat) = goat)),
#   ((move = c) → ¬(next(cabbage) = cabbage))],
#  'ltl': [¬F ((farmer = right) ∧ ((wolf = right) ∧ ((goat = right) ∧ (cabbage = right))))]}

# %%
from parse import parse

with open('examples/fairness.smv') as f:
    input = f.read()
parse(input)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedCharacters                      Traceback (most recent call last)
# Cell In[25], line 5
#       3 with open('examples/fairness.smv') as f:
#       4     input = f.read()
# ----> 5 parse(input)
#
# File f:\Projects\Bounded-Model-Checker\parse.py:13, in parse(text)
#      11 def parse(text):
#      12     parser = Lark(_grammar, start='start', ambiguity='resolve')
# ---> 13     tree = parser.parse(text)
#      14     declaration_parser = _DeclarationParser()
#      15     declaration_parser.visit(tree)
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\lark.py:677, in Lark.parse(self, text, start, on_error)
#     675 if on_error is not None and self.options.parser != 'lalr':
#     676     raise NotImplementedError("The on_error option is only implemented for the LALR(1) parser.")
# --> 677 return self.parser.parse(text, start=start, on_error=on_error)
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\parser_frontends.py:131, in ParsingFrontend.parse(self, text, start, on_error)
#     129 kw = {} if on_error is None else {'on_error': on_error}
#     130 stream = self._make_lexer_thread(text)
# --> 131 return self.parser.parse(stream, chosen_start, **kw)
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\parsers\earley.py:280, in Parser.parse(self, lexer, start)
#     277     else:
#     278         columns[0].add(item)
# --> 280 to_scan = self._parse(lexer, columns, to_scan, start_symbol)
#     282 # If the parse was successful, the start
#     283 # symbol should have been completed in the last step of the Earley cycle, and will be in
#     284 # this column. Find the item for the start_symbol, which is the root of the SPPF tree.
#     285 solutions = dedup_list(n.node for n in columns[-1] if n.is_complete and n.node is not None and n.s == start_symbol and n.start == 0)
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\parsers\xearley.py:153, in Parser._parse(self, stream, columns, to_scan, start_symbol)
#     150 for token in stream:
#     151     self.predict_and_complete(i, to_scan, columns, transitives, node_cache)
# --> 153     to_scan, node_cache = scan(i, to_scan)
#     155     if token == '\n':
#     156         text_line += 1
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\parsers\xearley.py:125, in Parser._parse.<locals>.scan(i, to_scan)
#     123 if not next_set and not delayed_matches and not next_to_scan:
#     124     considered_rules = list(sorted(to_scan, key=lambda key: key.rule.origin.name))
# --> 125     raise UnexpectedCharacters(stream, i, text_line, text_column, {item.expect.name for item in to_scan},
#     126                                set(to_scan), state=frozenset(i.s for i in to_scan),
#     127                                considered_rules=considered_rules
#     128                                )
#     130 return next_to_scan, node_cache
#
# UnexpectedCharacters: No terminal matches 'F' in the current parser context, at line 24 col 1
#
# FAIRNESS proc1 = critical
# ^
# Expected one of:
# 	* EQ
# 	* INIT
# 	* INVAR
# 	* LTLSPEC
# 	* OR
# 	* TRANS
# 	* VAR
# 	* NEQ
# 	* AND
# 	* IMPLIES
# 	* IN

# %%
from parse import parse

with open('examples/counter.smv') as f:
    input = f.read()
parse(input)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedCharacters                      Traceback (most recent call last)
# Cell In[20], line 5
#       3 with open('examples/counter.smv') as f:
#       4     input = f.read()
# ----> 5 parse(input)
#
# File f:\Projects\Bounded-Model-Checker\parse.py:13, in parse(text)
#      11 def parse(text):
#      12     parser = Lark(_grammar, start='start', ambiguity='resolve')
# ---> 13     tree = parser.parse(text)
#      14     declaration_parser = _DeclarationParser()
#      15     declaration_parser.visit(tree)
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\lark.py:677, in Lark.parse(self, text, start, on_error)
#     675 if on_error is not None and self.options.parser != 'lalr':
#     676     raise NotImplementedError("The on_error option is only implemented for the LALR(1) parser.")
# --> 677 return self.parser.parse(text, start=start, on_error=on_error)
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\parser_frontends.py:131, in ParsingFrontend.parse(self, text, start, on_error)
#     129 kw = {} if on_error is None else {'on_error': on_error}
#     130 stream = self._make_lexer_thread(text)
# --> 131 return self.parser.parse(stream, chosen_start, **kw)
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\parsers\earley.py:280, in Parser.parse(self, lexer, start)
#     277     else:
#     278         columns[0].add(item)
# --> 280 to_scan = self._parse(lexer, columns, to_scan, start_symbol)
#     282 # If the parse was successful, the start
#     283 # symbol should have been completed in the last step of the Earley cycle, and will be in
#     284 # this column. Find the item for the start_symbol, which is the root of the SPPF tree.
#     285 solutions = dedup_list(n.node for n in columns[-1] if n.is_complete and n.node is not None and n.s == start_symbol and n.start == 0)
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\parsers\xearley.py:153, in Parser._parse(self, stream, columns, to_scan, start_symbol)
#     150 for token in stream:
#     151     self.predict_and_complete(i, to_scan, columns, transitives, node_cache)
# --> 153     to_scan, node_cache = scan(i, to_scan)
#     155     if token == '\n':
#     156         text_line += 1
#
# File f:\Projects\Bounded-Model-Checker\.venv\Lib\site-packages\lark\parsers\xearley.py:125, in Parser._parse.<locals>.scan(i, to_scan)
#     123 if not next_set and not delayed_matches and not next_to_scan:
#     124     considered_rules = list(sorted(to_scan, key=lambda key: key.rule.origin.name))
# --> 125     raise UnexpectedCharacters(stream, i, text_line, text_column, {item.expect.name for item in to_scan},
#     126                                set(to_scan), state=frozenset(i.s for i in to_scan),
#     127                                considered_rules=considered_rules
#     128                                )
#     130 return next_to_scan, node_cache
#
# UnexpectedCharacters: No terminal matches '0' in the current parser context, at line 2 col 9
#
# VAR y : 0 .. 15;
#         ^
# Expected one of:
# 	* LBRACE
# 	* BOOLEANTYPE
